# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
dataset_url=requests.get("https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time-in-python",headers={"User-Agent":"Mozilla/5.0"})
dataset_url
# Out:
# <Response [200]>

# %%
dataset_url.text
# Out:
# '\n<!DOCTYPE html>\n\n\n    <html itemscope itemtype="https://schema.org/QAPage" class="html__responsive " lang="en">\n\n    <head>\n\n        <title>datetime - How do I get the current time in Python? - Stack Overflow</title>\n        <link rel="shortcut icon" href="https://cdn.sstatic.net/Sites/stackoverflow/Img/favicon.ico?v=ec617d715196">\n        <link rel="apple-touch-icon" href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a">\n        <link rel="image_src" href="https://cdn.sstatic.net/Sites/stackoverflow/Img/apple-touch-icon.png?v=c78bd457575a"> \n        <link rel="search" type="application/opensearchdescription+xml" title="Stack Overflow" href="/opensearch.xml">\n        <link rel="canonical" href="https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time-in-python" />\n    <meta name="viewport" content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0">\n        <meta name="bingbot" content=
# ...

# %%
soup=BeautifulSoup(dataset_url.text,"html.parser")

# %%
question=soup.find('a',class_='question-hyperlink')
# question.text
# Out:
# 'How do I get the current time in Python?'

# %%
answer=soup.find_all('div',class_='s-prose js-post-body')
num=1
for i in answer[1:]:
    print(f'{num} Answer:{i.text}')
    num+=1
# Out:
# 1 Answer:
# Use datetime:
# >>> import datetime
# >>> now = datetime.datetime.now()
# >>> now
# datetime.datetime(2009, 1, 6, 15, 8, 24, 78915)
# >>> print(now)
# 2009-01-06 15:08:24.789150
#
# For just the clock time without the date:
# >>> now.time()
# datetime.time(15, 8, 24, 78915)
# >>> print(now.time())
# 15:08:24.789150
#
#
# To save typing, you can import the datetime object from the datetime module:
# >>> from datetime import datetime
#
# Then remove the prefix datetime. from all of the above.
#
# 2 Answer:
# Use time.strftime():
# >>> from time import gmtime, strftime
# >>> strftime("%Y-%m-%d %H:%M:%S", gmtime())
# '2009-01-05 22:14:39'
#
#
# 3 Answer:
# from datetime import datetime
# datetime.now().strftime('%Y-%m-%d %H:%M:%S')
#
# Example output: '2013-09-18 11:16:32'
# See list of strftime directives.
#
# 4 Answer:
# Similar to Harley's answer, but use the str() function for a quick-n-dirty, slightly more human readable format:
# >>> from datetime import datetime
# ...
